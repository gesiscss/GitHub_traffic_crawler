# %%
from DataRetrieval import readJson

# %%
files = readJson.findJsonFiles()

# %%
print(files)
# Out:
# {'C:\\Users\\popovirr\\PycharmProjects\\GesisTraffic\\gh_traffic\\Repositories\\binderhub\\clones\\2018-07-10.json': Empty DataFrame
# Columns: [count, uniques, clones]
# Index: [], 'C:\\Users\\popovirr\\PycharmProjects\\GesisTraffic\\gh_traffic\\Repositories\\binderhub\\clones\\2018-07-16.json': Empty DataFrame
# Columns: [count, uniques, clones]
# Index: [], 'C:\\Users\\popovirr\\PycharmProjects\\GesisTraffic\\gh_traffic\\Repositories\\binderhub\\clones\\2018-07-26.json':    count  uniques                                             clones
# 0      1        1  {'timestamp': '2018-07-24T00:00:00Z', 'count':..., 'C:\\Users\\popovirr\\PycharmProjects\\GesisTraffic\\gh_traffic\\Repositories\\binderhub\\clones\\2018-07.json':    count  timestamp  uniques
# 0      1 2018-07-24        1, 'C:\\Users\\popovirr\\PycharmProjects\\GesisTraffic\\gh_traffic\\Repositories\\binderhub\\clones\\2018-08-06.json':    count  uniques                                             clones
# ...
